# %%
import pandas as pd
stations = pd.read_csv('stations.csv')
activity = pd.read_csv('activity_readings.csv')

# %%
#print(stations.head())
#print(stations.info())
#print(stations.count())

#print(activity.head())
#print(activity.info())
#print(activity.count())
stat = activity[activity['source_id'] == 'station-north-01']
stat = stat.sort_values(by='timestamp')
print(stat)

stat1 = activity[activity['source_id'] == 'station-north-02']
stat1 = stat1.sort_values(by='timestamp')
print(stat1)
# Out:
#      event_id         source_id             timestamp value
# 2      e00003  station-north-01  2026-09-09T08:00:00Z  44.5
# 10     e00011  station-north-01  2026-09-09T08:01:00Z  41.1
# 18     e00019  station-north-01  2026-09-09T08:02:00Z  42.1
# 26     e00027  station-north-01  2026-09-09T08:03:00Z  42.6
# 34     e00035  station-north-01  2026-09-09T08:04:00Z  37.5
# ...       ...               ...                   ...   ...
# 2054   e02055  station-north-01  2026-09-09T12:15:00Z  36.4
# 2062   e02063  station-north-01  2026-09-09T12:16:00Z  41.7
# 2070   e02071  station-north-01  2026-09-09T12:17:00Z  43.9
# 2078   e02079  station-north-01  2026-09-09T12:18:00Z  41.6
# 2086   e02087  station-north-01  2026-09-09T12:19:00Z  45.7
#
# [262 rows x 4 columns]
#      event_id         source_id             timestamp value
# 3      e00004  station-north-02  2026-09-09T08:00:00Z  62.5
# 11     e00012  station-north-02  2026-09-09T08:01:00Z  51.4
# ...
